# %%
API_KEY='fec055a537f44c58ae827c8e15a45dfc'
Team = 'Manchester United'

# %%
url = f"https://newsapi.org/v2/everything?q={Team}&sortBy=popularity&apiKey={API_KEY}"
r=requests.get(url)
r = r.json()
art = r['articles']
for a in art:
    print(a['url'])
    print(a['source']['name'])
    print(a['description'])
    print(a["urlToImage"])
# Out:
# https://www.bbc.co.uk/sport/football/63337723
# BBC News
# Cristiano Ronaldo will not be part of Manchester United's squad for Saturday's game at Chelsea.
# https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/11787/production/_124395517_bbcbreakingnewsgraphic.jpg
# https://www.bbc.co.uk/sport/football/63404717
# BBC News
# Manchester United cruise past Sheriff but will need to beat Real Sociedad in their Europa League Group E finale to take top spot.
# https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/84F8/production/_127404043_gettyimages-1244276951.jpg
# https://www.bbc.co.uk/sport/football/63225409
# BBC News
# Britain's richest man Sir Jim Ratcliffe says he is still interested in buying a Premier League club.
# https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/E48A/production/_127060585_gettyimages-1083147012.jpg
# https://www.bbc.co.uk/sport/football/63178900
# BBC News
# ...

# %%
import requests
from bs4 import BeautifulSoup

params = {
    "q": "manchester united news",
    "tbm": "nws", 
    "content-type": "image/gif",
}

html = requests.get("https://www.google.com/search", params=params)
soup = BeautifulSoup(html.text, 'html.parser')

for img in soup.select("img"):
      print(img["src"])
# Out:
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews(lang='en', period='1d')
googlenews.search('Manchester United')
res = googlenews.results()
googlenews.clear()

for result in res:
    print('\nMedia:', result['img'])
# Out:
# Media: ...: ...: ...: ...: ...: ...: ...: ...: ...: ...
